# %%
import pandas as pd

# %% [markdown]
# ## Questão 1

# %%
carla = (4.2 + 9 + 5.4) / 3
jose = (5.2 + 7.3 + 7) / 3
camila = 6.5
print(carla)
print(jose)
print(camila)
media = (carla + jose + camila) / 3
print(media) # -> Valor arredonda para 6.4

# %%
q1 = [carla, jose, camila, media]

# %% [markdown]
# ## Questão 2

# %%
df = pd.read_csv("https://github.com/marcelovc785/AP2_PML_8001/raw/main/IDSC_BR_AP2_E01d2G01.csv", encoding="latin1", sep=";", decimal=",").dropna()
df
# Out:
#              id             Territorialidade  População_Ref  \
# 0     5200050.0      ;Abadia de Goiás;GO;CO;        19128.0
# 1     3100104.0  ;Abadia dos Dourados;MG;SE;         6272.0
# 2     5200100.0            ;Abadiânia;GO;CO;        17228.0
# 3     3100203.0               ;Abaeté;MG;SE;        22675.0
# 4     1500107.0            ;Abaetetuba;PA;N;       158188.0
# ...         ...                          ...            ...
# 5565  2933604.0          ;Xique-Xique;BA;NE;        44757.0
# 5566  2517407.0               ;Zabelê;PB;NE;         2228.0
# 5567  3557154.0             ;Zacarias;SP;SE;         2692.0
# 5568  2114007.0              ;Zé Doca;MA;NE;        40801.0
# 5569  4219853.0                ;Zortéa;SC;S;         3930.0
#
#       Pontuação Indice ODS 2022  Classificação 2022  2022 ODS 1  2022 ODS 3  \
# 0                         48.06              2226.0       42.39       64.57
# 1                         45.65              3143.0       51.21       65.08
# ...

# %%
df["Territorialidade"] = df["Territorialidade"].str.strip(";")
df["Região"] = df["Territorialidade"].str.split(";", expand=True)[2]
df["Estado"] = df["Territorialidade"].str.split(";", expand=True)[1]
df["Cidade"] = df["Territorialidade"].str.split(";", expand=True)[0]

# ["", "Abadia de Goiás", "GO", "CO"]
df
# Out:
#              id           Territorialidade  População_Ref  \
# 0     5200050.0      Abadia de Goiás;GO;CO        19128.0
# 1     3100104.0  Abadia dos Dourados;MG;SE         6272.0
# 2     5200100.0            Abadiânia;GO;CO        17228.0
# 3     3100203.0               Abaeté;MG;SE        22675.0
# 4     1500107.0            Abaetetuba;PA;N       158188.0
# ...         ...                        ...            ...
# 5565  2933604.0          Xique-Xique;BA;NE        44757.0
# 5566  2517407.0               Zabelê;PB;NE         2228.0
# 5567  3557154.0             Zacarias;SP;SE         2692.0
# 5568  2114007.0              Zé Doca;MA;NE        40801.0
# 5569  4219853.0                Zortéa;SC;S         3930.0
#
#       Pontuação Indice ODS 2022  Classificação 2022  2022 ODS 1  2022 ODS 3  \
# 0                         48.06              2226.0       42.39       64.57
# 1                         45.65              3143.0       51.21       65.08
# ...

# %%
df2 = df.filter(items=["Região", "Estado", "Cidade", 'População_Ref', 'Pontuação Indice ODS 2022',
       'Classificação 2022', '2022 ODS 1', '2022 ODS 3', '2022 ODS 5',
       'Pontuação Indice ODS 2019', 'Classificação 2019', '2019 ODS 1',
       '2019 ODS 3', '2019 ODS 5'])
df2
# Out:
#      Região Estado               Cidade  População_Ref  \
# 0        CO     GO      Abadia de Goiás        19128.0
# 1        SE     MG  Abadia dos Dourados         6272.0
# 2        CO     GO            Abadiânia        17228.0
# 3        SE     MG               Abaeté        22675.0
# 4         N     PA           Abaetetuba       158188.0
# ...     ...    ...                  ...            ...
# 5565     NE     BA          Xique-Xique        44757.0
# 5566     NE     PB               Zabelê         2228.0
# 5567     SE     SP             Zacarias         2692.0
# 5568     NE     MA              Zé Doca        40801.0
# 5569      S     SC               Zortéa         3930.0
#
#       Pontuação Indice ODS 2022  Classificação 2022  2022 ODS 1  2022 ODS 3  \
# 0                         48.06              2226.0       42.39       64.57
# 1                         45.65              3143.0       51.21       65.08
# ...

# %% [markdown]
# ## 01) O estado da região Sudeste que teve o menor valor na média da “Coluna 2 do Ano2”, organizada por “UF” foi Minas Gerais.

# %% [markdown]
# # Questão 3

# %% [markdown]
# ## 01) O estado da região Nordeste que teve o maior valor na média da “Coluna 3 do Ano2, organizada por “UF” foi o Ceará.

# %%
df_NE = df2.where(df2["Região"] == "NE").dropna()
df_NE
# Out:
#      Região Estado               Cidade  População_Ref  \
# 5        NE     CE              Abaiara        10038.0
# 6        NE     BA               Abaíra         7301.0
# 7        NE     BA                Abaré        17639.0
# 13       NE     PE         Abreu e Lima        98462.0
# 16       NE     MA           Açailândia       106550.0
# ...     ...    ...                  ...            ...
# 5553     NE     BA  Wenceslau Guimarães        24474.0
# 5563     NE     PE                Xexéu        11611.0
# 5565     NE     BA          Xique-Xique        44757.0
# 5566     NE     PB               Zabelê         2228.0
# 5568     NE     MA              Zé Doca        40801.0
#
#       Pontuação Indice ODS 2022  Classificação 2022  2022 ODS 1  2022 ODS 3  \
# 5                         42.91              4104.0       38.53       72.90
# 6                         45.07              3361.0       43.74       74.64
# ...

# %%
media = df_NE.groupby("Estado")["2022 ODS 5"].mean()
media
# Out:
# Estado
# AL    12.546471
# BA    23.937434
# CE    25.842826
# MA    20.652581
# PB     8.563274
# PE    13.847189
# PI    18.951473
# RN    12.543653
# SE    17.942133
# Name: 2022 ODS 5, dtype: float64

# %%
q3_1 = "Verdadeiro"

# %% [markdown]
# ## 02) A cidade do estado que responde corretamente o item anterior e que teve o maior crescimento da “Coluna 3” entre os anos 1 e 2 foi Viçosa do Ceará.

# %%
df2["Taxa_cresc ODS 3"] = (df2["2022 ODS 3"] - df2["2019 ODS 3"]) / df2["2019 ODS 3"]
df2
# Out:
#      Região Estado               Cidade  População_Ref  \
# 0        CO     GO      Abadia de Goiás        19128.0
# 1        SE     MG  Abadia dos Dourados         6272.0
# 2        CO     GO            Abadiânia        17228.0
# 3        SE     MG               Abaeté        22675.0
# 4         N     PA           Abaetetuba       158188.0
# ...     ...    ...                  ...            ...
# 5565     NE     BA          Xique-Xique        44757.0
# 5566     NE     PB               Zabelê         2228.0
# 5567     SE     SP             Zacarias         2692.0
# 5568     NE     MA              Zé Doca        40801.0
# 5569      S     SC               Zortéa         3930.0
#
#       Pontuação Indice ODS 2022  Classificação 2022  2022 ODS 1  2022 ODS 3  \
# 0                         48.06              2226.0       42.39       64.57
# 1                         45.65              3143.0       51.21       65.08
# ...

# %%
q3_2 = df2["Cidade"].loc[df2["Taxa_cresc ODS 3"] == df2.where(df2["Estado"] == "CE")["Taxa_cresc ODS 3"].max()]
q3_2

q3_2 = "Falso"
# Out:
# 475    Banabuiú
# Name: Cidade, dtype: object

# %% [markdown]
# ## 04) O valor da “População_Ref” na cidade que responde corretamente o item anterior é 57912.

# %%
df2["População_Ref"].loc[475]

q3_4 = "Falso"
# Out:
# 17195.0

# %% [markdown]
# ## 08) Aproximadamente, a média da Pontuação Índice ODS entre os anos 1 e 2 da região Sudeste foi 51.79.

# %%
df_SE = df2.where(df2["Região"] == "SE").dropna()
df_SE
# Out:
#      Região Estado               Cidade  População_Ref  \
# 1        SE     MG  Abadia dos Dourados         6272.0
# 3        SE     MG               Abaeté        22675.0
# 12       SE     MG           Abre Campo        13927.0
# 15       SE     MG              Acaiaca         3909.0
# 29       SE     MG              Açucena         8943.0
# ...     ...    ...                  ...            ...
# 5544     SE     RJ        Volta Redonda       261584.0
# 5545     SE     SP           Votorantim       127923.0
# 5546     SE     SP          Votuporanga        96634.0
# 5551     SE     MG       Wenceslau Braz         2356.0
# 5567     SE     SP             Zacarias         2692.0
#
#       Pontuação Indice ODS 2022  Classificação 2022  2022 ODS 1  2022 ODS 3  \
# 1                         45.65              3143.0       51.21       65.08
# 3                         52.73               899.0       47.13       77.96
# ...

# %%
media1 = df_SE["Pontuação Indice ODS 2022"].mean()
media2 = df_SE["Pontuação Indice ODS 2019"].mean()

media_final_se = (media1 + media2) / 2
media_final_se

q3_8 = "Verdadeiro"
# Out:
# 51.78826438848921

# %% [markdown]
# ## 16) A porcentagem de cidades da região Nordeste que estão acima da média da Pontuação Índice ODS da região Sudeste está entre 0.5% e 1.0%
